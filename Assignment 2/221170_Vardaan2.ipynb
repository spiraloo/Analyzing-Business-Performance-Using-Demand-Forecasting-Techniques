# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Exercises

**Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**

*Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
sns.jointplot(x='fare',y='age',data=titanic,kind='scatter',palette="deep")
plt.xlim([-100,600])
# Out:
# (-100.0, 600.0)

# %%
sns.histplot(titanic['fare'],kde=False,bins=30)
plt.ylim([0,500])
plt.xlim([0,600])
# Out:
# (0.0, 600.0)

# %%
sns.histplot(titanic['fare'], bins=10, kde=False,color='pink')
plt.ylim([0,500])
plt.xlim([0,600])
# Out:
# (0.0, 600.0)

# %%
sns.boxplot(x="class", y="age", data=titanic,palette='rainbow')
plt.ylim([0,80])
# Out:
# (0.0, 80.0)

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot data1 in the first subplot
sns.scatterplot(x=data1['x'], y=data1['y'], ax=axes[0, 0])
axes[0, 0].set_title('Scatter Plot 1')

# Plot data2 in the second subplot
sns.histplot(data2['values'], ax=axes[0, 1], color='green')
axes[0, 1].set_title('Histogram')

# Plot data3 in the third subplot
sns.lineplot(x=data3['x'], y=data3['y'], ax=axes[1, 0], color='red')
axes[1, 0].set_title('Line Plot')

# Remove empty subplot
fig.delaxes(axes[1, 1])

# Adjust spacing between subplots
plt.tight_layout()

# Display the subplots
plt.show()

# %%
sns.scatterplot(x=x, y=y, color='blue')
plt.xlabel('First')
plt.ylabel('age')

# %%
sns.countplot(x='sex',data=titanic,palette=[sns.color_palette("deep")[0], sns.color_palette("deep")[2]])
plt.ylim([0,600])
# Out:
# (0.0, 600.0)

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm')
# Out:
# <ipython-input-12-058ad0525d88>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),cmap='coolwarm')
# <Axes: >

# %%
x = sns.FacetGrid(titanic,col="sex",palette="deep")
x = x.map(plt.hist, "age")
plt.ylim([0,120])
plt.xlim([0,80])
plt.xticks([0,10,20,30,40,50,60,70,80])
# Out:
# ([<matplotlib.axis.XTick at 0x7f4c47c8db70>,
# ...
#  [Text(0, 0, '0'),
#   Text(10, 0, '10'),
#   Text(20, 0, '20'),
#   Text(30, 0, '30'),
#   Text(40, 0, '40'),
#   Text(50, 0, '50'),
#   Text(60, 0, '60'),
#   Text(70, 0, '70'),
#   Text(80, 0, '80')])

# %%
x = sns.FacetGrid(titanic,col="sex")
x = x.map(plt.hist, "age")
plt.ylim([0,120])
plt.xlim([0,80])
plt.xticks([0,10,20,30,40,50,60,70,80])
# Out:
# ([<matplotlib.axis.XTick at 0x7f4c48e4c610>,
# ...
#  [Text(0, 0, '0'),
#   Text(10, 0, '10'),
#   Text(20, 0, '20'),
#   Text(30, 0, '30'),
#   Text(40, 0, '40'),
#   Text(50, 0, '50'),
#   Text(60, 0, '60'),
#   Text(70, 0, '70'),
#   Text(80, 0, '80')])

# %% [markdown]
# # Great Job!
